-- %% [markdown]
-- # Lesson 11: SQL Part 2 Studio
--
-- > This studio asks you to create queries using the functions from this lesson. As you work through the studio, you may need to create more than one query to return the desired answer.  For others, you may need to combine functions together in order to answer the original query.  The questions have been organized in a way to help you puzzle out the answers.
-- >
-- > Happy querying!
--
-- **The Dataset:**
--
-- > We will be working with the **BooksDB dataset** from Lesson 10.  You should already have access to it.

-- %% [markdown]
-- ## The Questions:

-- %% [markdown]
-- 1.  Create a query that returns the longest title in the dataset.  We can do this in two steps.
--
-- > A. Create a query that returns the length of the longest title.
-- >
-- > B. Create a query that uses the length you found in step A to find the longest title.

-- %%
-- Code here:
SELECT len(MAX(title)) from BooksDB.dbo.books;
SELECT title FROM BooksDB.dbo.books where LEN(title)=58;
SELECT title FROM BooksDB.dbo.books where LEN(title)=(SELECT len(MAX(title)) from BooksDB.dbo.books);
-- Out:
-- (1 row affected)
-- (56 rows affected)
-- (56 rows affected)
-- Total execution time: 00:00:00.185
-- <table><tr><th>(No column name)</th></tr><tr><td>58</td></tr></table>
-- <table><tr><th>title</th></tr><tr><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td></tr><tr><td>Batman: The Dark Knight Returns (The Dark Knight Saga, #1)</td></tr><tr><td>Lamb: The Gospel According to Biff, Christ's Childhood Pal</td></tr><tr><td>Life, the Universe and Everything (Hitchhiker's Guide, #3)</td></tr><tr><td>The Four Agreements: A Practical Guide to Personal Freedom</td></tr><tr><td>The Black Echo (Harry Bosch, #1; Harry Bosch Universe, #1)</td></tr><tr><td>Four: A Divergent Story Collection (Divergent, #0.1 - 0.4)</td></tr><tr><td>A Court of Mist and Fury (A Court of Thorns and Roses, #2)</td></tr><tr><td>The Prayer of Jabez:  Breaking Through to the Blessed Life</td></tr><tr><td>Zero to One: Notes on Startups, or How to Build the Future</td></tr><tr><td>Getting to Yes: Negotiating an Agreement Without Giving In</td></tr><tr><td>The Virgin's Lover (The Plantagenet and Tudor Novels, #13)</td></tr><tr><td>Left to Tell: Discovering God Amidst the Rwandan Holocaust</td></tr><tr><td>The Philosophy of Andy Warhol (From A to B and Back Again)</td></tr><tr><td>Wicked Deeds on a Winter's Night (Immortals After Dark #4)</td></tr><tr><td>Gregor and the Prophecy of Bane (Underland Chronicles, #2)</td></tr><tr><td>I Shall Wear Midnight (Discworld, #38; Tiffany Aching, #4)</td></tr><tr><td>Love You More (Tessa Leoni, #1; Detective D.D. Warren, #5)</td></tr><tr><td>Buffy the Vampire Slayer: The Long Way Home (Season 8, #1)</td></tr><tr><td>City of Bones (Harry Bosch, #8; Harry Bosch Universe, #10)</td></tr><tr><td>Encyclopedia Brown, Boy Detective (Encyclopedia Brown, #1)</td></tr><tr><td>How the Light Gets In (Chief Inspector Armand Gamache, #9)</td></tr><tr><td>A Rule Against Murder (Chief Inspector Armand Gamache, #4)</td></tr><tr><td>美少女戦士セーラームーン新装版 1 [Bishōjo Senshi Sailor Moon Shinsōban 1]</td></tr><tr><td>Fairy Tales from the Brothers Grimm: A New English Version</td></tr><tr><td>The Beautiful Mystery (Chief Inspector Armand Gamache, #8)</td></tr><tr><td>First King of Shannara (The Original Shannara Trilogy, #0)</td></tr><tr><td>The Overlook (Harry Bosch, #13; Harry Bosch Universe, #15)</td></tr><tr><td>The Irresistible Revolution: Living as an Ordinary Radical</td></tr><tr><td>Falling Leaves: The Memoir of an Unwanted Chinese Daughter</td></tr><tr><td>Books of Blood: Volumes One to Three (Books of Blood #1-3)</td></tr><tr><td>The Game: Penetrating the Secret Society of Pickup Artists</td></tr><tr><td>Chinese Cinderella: The True Story of an Unwanted Daughter</td></tr><tr><td>Y: The Last Man, Vol. 7: Paper Dolls (Y: The Last Man, #7)</td></tr><tr><td>The Ancestor's Tale: A Pilgrimage to the Dawn of Evolution</td></tr><tr><td>No god but God: The Origins, Evolution and Future of Islam</td></tr><tr><td>Sherlock Holmes: The Complete Novels and Stories, Volume I</td></tr><tr><td>Always Looking Up: The Adventures of an Incurable Optimist</td></tr><tr><td>My Stroke of Insight: A Brain Scientist's Personal Journey</td></tr><tr><td>Lament: The Faerie Queen's Deception (Books of Faerie, #1)</td></tr><tr><td>The Endurance: Shackleton's Legendary Antarctic Expedition</td></tr><tr><td>The Unwritten, Vol. 1: Tommy Taylor and the Bogus Identity</td></tr><tr><td>Damaged: The Heartbreaking True Story of a Forgotten Child</td></tr><tr><td>How to Talk So Kids Will Listen &amp; Listen So Kids Will Talk</td></tr><tr><td>The War that Saved My Life (The War That Saved My Life #1)</td></tr><tr><td>A Homemade Life: Stories and Recipes from My Kitchen Table</td></tr><tr><td>The Better Angels of Our Nature: Why Violence Has Declined</td></tr><tr><td>The Darkness That Comes Before (The Prince of Nothing, #1)</td></tr><tr><td>Upon the Midnight Clear (Dark-Hunter #12, Dream-Hunter #2)</td></tr><tr><td>To Sell Is Human: The Surprising Truth About Moving Others</td></tr><tr><td>Monster Hunter Vendetta (Monster Hunter International, #2)</td></tr><tr><td>The Residence: Inside the Private World of the White House</td></tr><tr><td>Pandor ...
-- <table><tr><th>title</th></tr><tr><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td></tr><tr><td>Batman: The Dark Knight Returns (The Dark Knight Saga, #1)</td></tr><tr><td>Lamb: The Gospel According to Biff, Christ's Childhood Pal</td></tr><tr><td>Life, the Universe and Everything (Hitchhiker's Guide, #3)</td></tr><tr><td>The Four Agreements: A Practical Guide to Personal Freedom</td></tr><tr><td>The Black Echo (Harry Bosch, #1; Harry Bosch Universe, #1)</td></tr><tr><td>Four: A Divergent Story Collection (Divergent, #0.1 - 0.4)</td></tr><tr><td>A Court of Mist and Fury (A Court of Thorns and Roses, #2)</td></tr><tr><td>The Prayer of Jabez:  Breaking Through to the Blessed Life</td></tr><tr><td>Zero to One: Notes on Startups, or How to Build the Future</td></tr><tr><td>Getting to Yes: Negotiating an Agreement Without Giving In</td></tr><tr><td>The Virgin's Lover (The Plantagenet and Tudor Novels, #13)</td></tr><tr><td>Left to Tell: Discovering God Amidst the Rwandan Holocaust</td></tr><tr><td>The Philosophy of Andy Warhol (From A to B and Back Again)</td></tr><tr><td>Wicked Deeds on a Winter's Night (Immortals After Dark #4)</td></tr><tr><td>Gregor and the Prophecy of Bane (Underland Chronicles, #2)</td></tr><tr><td>I Shall Wear Midnight (Discworld, #38; Tiffany Aching, #4)</td></tr><tr><td>Love You More (Tessa Leoni, #1; Detective D.D. Warren, #5)</td></tr><tr><td>Buffy the Vampire Slayer: The Long Way Home (Season 8, #1)</td></tr><tr><td>City of Bones (Harry Bosch, #8; Harry Bosch Universe, #10)</td></tr><tr><td>Encyclopedia Brown, Boy Detective (Encyclopedia Brown, #1)</td></tr><tr><td>How the Light Gets In (Chief Inspector Armand Gamache, #9)</td></tr><tr><td>A Rule Against Murder (Chief Inspector Armand Gamache, #4)</td></tr><tr><td>美少女戦士セーラームーン新装版 1 [Bishōjo Senshi Sailor Moon Shinsōban 1]</td></tr><tr><td>Fairy Tales from the Brothers Grimm: A New English Version</td></tr><tr><td>The Beautiful Mystery (Chief Inspector Armand Gamache, #8)</td></tr><tr><td>First King of Shannara (The Original Shannara Trilogy, #0)</td></tr><tr><td>The Overlook (Harry Bosch, #13; Harry Bosch Universe, #15)</td></tr><tr><td>The Irresistible Revolution: Living as an Ordinary Radical</td></tr><tr><td>Falling Leaves: The Memoir of an Unwanted Chinese Daughter</td></tr><tr><td>Books of Blood: Volumes One to Three (Books of Blood #1-3)</td></tr><tr><td>The Game: Penetrating the Secret Society of Pickup Artists</td></tr><tr><td>Chinese Cinderella: The True Story of an Unwanted Daughter</td></tr><tr><td>Y: The Last Man, Vol. 7: Paper Dolls (Y: The Last Man, #7)</td></tr><tr><td>The Ancestor's Tale: A Pilgrimage to the Dawn of Evolution</td></tr><tr><td>No god but God: The Origins, Evolution and Future of Islam</td></tr><tr><td>Sherlock Holmes: The Complete Novels and Stories, Volume I</td></tr><tr><td>Always Looking Up: The Adventures of an Incurable Optimist</td></tr><tr><td>My Stroke of Insight: A Brain Scientist's Personal Journey</td></tr><tr><td>Lament: The Faerie Queen's Deception (Books of Faerie, #1)</td></tr><tr><td>The Endurance: Shackleton's Legendary Antarctic Expedition</td></tr><tr><td>The Unwritten, Vol. 1: Tommy Taylor and the Bogus Identity</td></tr><tr><td>Damaged: The Heartbreaking True Story of a Forgotten Child</td></tr><tr><td>How to Talk So Kids Will Listen &amp; Listen So Kids Will Talk</td></tr><tr><td>The War that Saved My Life (The War That Saved My Life #1)</td></tr><tr><td>A Homemade Life: Stories and Recipes from My Kitchen Table</td></tr><tr><td>The Better Angels of Our Nature: Why Violence Has Declined</td></tr><tr><td>The Darkness That Comes Before (The Prince of Nothing, #1)</td></tr><tr><td>Upon the Midnight Clear (Dark-Hunter #12, Dream-Hunter #2)</td></tr><tr><td>To Sell Is Human: The Surprising Truth About Moving Others</td></tr><tr><td>Monster Hunter Vendetta (Monster Hunter International, #2)</td></tr><tr><td>The Residence: Inside the Private World of the White House</td></tr><tr><td>Pandor ...

-- %% [markdown]
-- 2.  Use what you learned in question 1 to find the shortest author name.
--
-- > A. Create a query that returns the length of the shortest author.
-- >
-- > B. Create a query that returns the shortest author's name.

-- %%
-- Code here:
SELECT LEN(MIN(authors)) from BooksDB.dbo.books;
SELECT authors FROM BooksDB.dbo.books WHERE LEN(authors)=16;
td></tr><tr><td>Charlaine Harris</td></tr><tr><td>Karen Joy Fowler</td></tr><tr><td>Orson Scott Card</td></tr><tr><td>Frank E. Peretti</td></tr><tr><td>Jessica Sorensen</td></tr><tr><td>Kelley Armstrong</td></tr><tr><td>Kelley Armstrong</td></tr><tr><td>James S.A. Corey</td></tr><tr><td>Michael Crichton</td></tr><tr><td>David Wroblewski</td></tr><tr><td>Charles Bukowski</td></tr><tr><td>Malcolm Gladwell</td></tr><tr><td>Carson McCullers</td></tr><tr><td>Lynne Reid Banks</td></tr><tr><td>Simon Winchester</td></tr><tr><td>Chuck Klosterman</td></tr><tr><td>Scott Westerfeld</td></tr><tr><td>Deborah Harkness</td></tr><tr><td>Robert K. Massie</td></tr><tr><td>Charles Bukowski</td></tr><tr><td>Robert McCloskey</td></tr><tr><td>W. Bruce Cameron</td></tr><tr><td>Philippa Gregory</td></tr><tr><td>Lauren DeStefano</td></tr><tr><td>Philippa Gregory</td></tr><tr><td>Colson Whitehead</td></tr><tr><td>Sharon M. Draper</td></tr><tr><td>Michael Crichton</td></tr><tr><td>Charlaine Harris</td></tr><tr><td>Michael Crichton</td></tr><tr><td>Raymond E. Feist</td></tr><tr><td>Dashiell Hammett</td></tr><tr><td>Michael Connelly</td></tr><tr><td>Adriana Trigiani</td></tr><tr><td>Anthony Horowitz</td></tr><tr><td>Orson Scott Card ...

-- %% [markdown]
-- 3\. How many titles contain the word "The"?
--
--
--
-- > A. Is there a difference between the number of titles that use "The" or "the"?

-- %%
-- Code here:
SELECT title FROM BooksDB.dbo.books WHERE title Like 'The %';
SELECT title FROM BooksDB.dbo.books WHERE title Like 'the %';
--there is no difference
-- Out:
-- (2832 rows affected)
-- (2832 rows affected)
-- Total execution time: 00:00:00.305
-- <table><tr><th>title</th></tr><tr><td>The Hunger Games (The Hunger Games, #1)</td></tr><tr><td>The Great Gatsby</td></tr><tr><td>The Fault in Our Stars</td></tr><tr><td>The Hobbit</td></tr><tr><td>The Catcher in the Rye</td></tr><tr><td>The Kite Runner</td></tr><tr><td>The Diary of a Young Girl</td></tr><tr><td>The Girl with the Dragon Tattoo (Millennium, #1)</td></tr><tr><td>The Fellowship of the Ring (The Lord of the Rings, #1)</td></tr><tr><td>The Lovely Bones</td></tr><tr><td>The Da Vinci Code (Robert Langdon, #2)</td></tr><tr><td>The Help</td></tr><tr><td>The Alchemist</td></tr><tr><td>The Giver (The Giver, #1)</td></tr><tr><td>The Lion, the Witch, and the Wardrobe (Chronicles of Narnia, #1)</td></tr><tr><td>The Time Traveler's Wife</td></tr><tr><td>The Lightning Thief (Percy Jackson and the Olympians, #1)</td></tr><tr><td>The Notebook (The Notebook, #1)</td></tr><tr><td>The Book Thief</td></tr><tr><td>The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy, #1)</td></tr><tr><td>The Secret Life of Bees</td></tr><tr><td>The Adventures of Huckleberry Finn</td></tr><tr><td>The Curious Incident of the Dog in the Night-Time</td></tr><tr><td>The Girl on the Train</td></tr><tr><td>The Golden Compass (His Dark Materials, #1)</td></tr><tr><td>The Perks of Being a Wallflower</td></tr><tr><td>The Shining (The Shining #1)</td></tr><tr><td>The Host (The Host, #1)</td></tr><tr><td>The Devil Wears Prada (The Devil Wears Prada, #1)</td></tr><tr><td>The Odyssey</td></tr><tr><td>The
Peel Pie Society</td></tr><tr><td>The Color Purple</td></tr><tr><td>The Lost Symbol (Robert Langdon, #3)</td></tr><tr><td>The Selection (The Selection, #1)</td></tr><tr><td>The Immortal Life of Henrietta Lacks</td></tr><tr><td>The Silence of the Lambs  (Hannibal Lecter, #2)</td></tr><tr><td>The Metamorphosis</td></tr><tr><td>The Titan's Curse (Percy Jackson and the Olympians, #3)</td></tr><tr><td>The Art o ...

-- %% [markdown]
-- 4.  How many authors' names _start_ with 'Z'?

-- %%
-- Code here:
SELECT count(authors) FROM BooksDB.dbo.books WHERE authors LIKE 'Z%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.055
-- <table><tr><th>(No column name)</th></tr><tr><td>11</td></tr></table>

-- %% [markdown]
-- 5\. How many books have been identified as printed in a language other than English?  There are four language codes for English: 'en', 'eng', 'en-US', and 'en-UK'.  Use LEFT to answer the question.  (Do not use the wildcard)
--
-- You might want to use one of these [comparison operators](https://docs.microsoft.com/en-us/sql/t-sql/language-elements/comparison-operators-transact-sql?view=sql-server-ver15).

-- %%
-- Code here:
SELECT COUNT(book_id) FROM BooksDB.dbo.books WHERE language_code Not IN ('en','eng','en-US','en-UK');
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.050
-- <table><tr><th>(No column name)</th></tr><tr><td>501</td></tr></table>

-- %% [markdown]
-- 6\. Retry question 5 using SUBSTRING.

-- %%
-- Code here:
SELECT COUNT(book_id) FROM BooksDB.dbo.books WHERE SUBSTRING(language_code,1,5)  Not IN ('en','eng','en-US','en-UK');
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.072
-- <table><tr><th>(No column name)</th></tr><tr><td>501</td></tr></table>

-- %% [markdown]
-- 7.  Create a column that returns the title, authors, and language codes.  Concatenate these elements so that they return in the following way: title by authors in language\_code language.
--
-- > A.  Check each selected column to see where any values are NULL.  Did any of the columns contain NULL values?  If so, which one?

-- %%
-- Code here:

SELECT top 10 FORMATMESSAGE('%s by %s in %s language', title, authors, language_code) AS Result from BooksDB.dbo.books;
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.419
-- <table><tr><th>Result</th></tr><tr><td>The Hunger Games (The Hunger Games, #1) by Suzanne Collins in eng language</td></tr><tr><td>Harry Potter and the Sorcerer's Stone (Harry Potter, #1) by J.K. Rowling, Mary GrandPré in eng language</td></tr><tr><td>Twilight (Twilight, #1) by Stephenie Meyer in en-US language</td></tr><tr><td>To Kill a Mockingbird by Harper Lee in eng language</td></tr><tr><td>The Great Gatsby by F. Scott Fitzgerald in eng language</td></tr><tr><td>The Fault in Our Stars by John Green in eng language</td></tr><tr><td>The Hobbit by J.R.R. Tolkien in en-US language</td></tr><tr><td>The Catcher in the Rye by J.D. Salinger in eng language</td></tr><tr><td>Angels &amp; Demons  (Robert Langdon, #1) by Dan Brown in en-CA language</td></tr><tr><td>Pride and Prejudice by Jane Austen in eng language</td></tr></table>

-- %% [markdown]
-- 8.  Update the query in question 7 using COALESCE to change the language code values from NULL to 'unknown'.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.057

-- %% [markdown]
-- 9\. Revisit question 7 using ISNULL instead of COALESCE.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.056
